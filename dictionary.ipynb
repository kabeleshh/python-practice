# %%
# dictionary

user1 = {'name':'xyz','age':24,'dept':'cse'}

print(user1)
# Out:
# {'name': 'xyz', 'age': 24, 'dept': 'cse'}

# %%
print(user1[age])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(user1[age])
#
# NameError: name 'age' is not defined

# %%
print(user1['age'])
# Out:
# 24

# %%
#add

user1['gender'] = 'Male'
print(user1)
# Out:
# {'name': 'xyz', 'age': 24, 'dept': 'cse', 'gender': 'Male'}

# %%
#modify

user1['age'] = 26
print(user1)
# Out:
# {'name': 'xyz', 'age': 26, 'dept': 'cse', 'gender': 'Male'}

# %%
#delete

del user1['dept']
print(user1)
# Out:
# {'name': 'xyz', 'age': 26, 'gender': 'Male'}

# %%
user1['dept'] = 'ece'
print(user1)
# Out:
# {'name': 'xyz', 'age': 26, 'gender': 'Male', 'dept': 'ece'}

# %%
#loop in dictionaries

for key,val in user1.items():
    print(key+' '+str(val))
# Out:
# name xyz
# age 26
# gender Male
# dept ece

# %%
for key in user1.keys():
    print(key)
# Out:
# name
# age
# gender
# dept

# %%
for val in user1.values():
    print(val)
# Out:
# xyz
# 26
# Male
# ece

# %%
# in sorted form

user1['name'] = 'abc'

for key,val in sorted(user1.items()):
    print(val)                    # keys are only arranged in ascending
# Out:
# 26
# ece
# Male
# abc

# %%
#list of dictionaries

users = []

user2 = {'name':'kabe','age':32,'dept':'eee'}
users.append(user2)

user3 = {'name':'Dhar','age':26,'dept':'auto'}
users.append(user3)

user4 = {'name':'bcd','age':77,'dept':'it'}
users.append(user4)

print(users)
# Out:
# [{'name': 'kabe', 'age': 32, 'dept': 'eee'}, {'name': 'Dhar', 'age': 26, 'dept': 'auto'}, {'name': 'bcd', 'age': 77, 'dept': 'it'}]

# %%
# lists in dictionary

x = {'name':'helloWorld','age':2026,'countries':['India','Russia','America'],'contients':['Asia','Africa','Australia']}

print(x)
# Out:
# {'name': 'helloWorld', 'age': 2026, 'countries': ['India', 'Russia', 'America'], 'contients': ['Asia', 'Africa', 'Australia']}

# %%
# exercise
