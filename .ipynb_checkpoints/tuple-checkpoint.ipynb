# %%
#tuple

t_1 = (1,44,5,22)
t_1[2] = 3
print(t_1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 #tuple
#       3 t_1 = (1,44,5,22)
# ----> 4 t_1[2] = 3
#       5 print(t_1)
#
# TypeError: 'tuple' object does not support item assignment

# %%
print(t_1[3])
print(t_1[1])
# Out:
# 22
# 44

# %%
t_1 = (76,1,34,86)
print(t_1)
# Out:
# (76, 1, 34, 86)

# %%
#We can't change specific value in tuple, instead we can access a specifc value or modify th entire tuple

# %%
print(t_1.index(34))
print(t_1.index(33))
# Out:
# 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 print(t_1.index(34))
# ----> 2 print(t_1.index(33))
#
# ValueError: tuple.index(x): x not in tuple

# %%
print(t_1.count(34))
# Out:
# 1

# %%
for i in t_1:
    print(i)
# Out:
# 76
# 1
# 34
# 86

# %%
if 86 in t_1:
    print("yes...We got it")
# Out:
# yes...We got it

# %%
if 23 in t_1:
    print("Yes...We got it")
print("Nope...")
# Out:
# Nope...

# %%
if 24 not in t_1:
    print("Yes...We got it")
print("Thank You")
# Out:
# Yes...We got it
# Thank You

# %%
if t_1:
    print(t_1)
# Out:
# (76, 1, 34, 86)
