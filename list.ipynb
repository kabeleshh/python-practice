# %%
x = ["abc","def","ghi","jkl"]
y = [2,4,1,7,44,2,77,21]
z = ["dfg",45,"wer",98]

# %%
#modify
x[2] = "xyz"
print(x)
# Out:
# ['abc', 'def', 'xyz', 'jkl']

# %%
#insert
y.insert(2,11)
print(y)
# Out:
# [2, 4, 11, 1, 7, 44, 2, 77, 21]

# %%
#append
z.append("tyu")
print(z)
# Out:
# ['dfg', 45, 'wer', 98, 'tyu']

# %%
#removing using index
del x[2]
print(x)
# Out:
# ['abc', 'def', 'jkl']

# %%
a = y.pop()
print(str(a)+" has been removed successfully")
print(y)
# Out:
# 44 has been removed successfully
# [2, 4, 11, 1, 7]

# %%
#removing using direct value
z.remove(45)
print(z)
# Out:
# ['dfg', 'wer', 98, 'tyu']

# %%
#temporary sort
print(sorted(y))
# Out:
# [1, 2, 4, 7, 11]

# %%
#permanent sort and reverse
y.sort()
#z.sort()  # error occurs because diff data types

y.append(2)
print(y)
# Out:
# [1, 2, 2, 2, 2, 4, 7, 11, 2]

# %%
y.remove(2)   # remove only one time

# %%
print(y)
# Out:
# [1, 4, 7, 11, 2, 2, 2, 2]

# %%
z.reverse()

# %%
print(z)
# Out:
# ['tyu', 98, 'wer', 'dfg']

# %%
z.sort()
print(z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 z.sort()
#       2 print(z)
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
b = len(y)
print(b)
# Out:
# 9

# %%
print(y)
# Out:
# [1, 2, 2, 2, 2, 4, 7, 11, 2]
