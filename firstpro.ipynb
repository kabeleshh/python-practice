# %%
x = "Kabelesh Dharshan"

# %%
print(x[0:4])
# Out:
# Kabe

# %%
print(x[3:8])
# Out:
# elesh

# %%
print(x[9:17])
print(x[0:8:2])
# Out:
# Dharshan
# Kbls

# %%
print(x[-1:-5])

# %%
print(x[-1:-5])

# %%
print(x[-1:-5:-1])
# Out:
# nahs

# %%
print(x[-5:-1])
# Out:
# rsha

# %%
print(x[-8:])
# Out:
# Dharshan

# %%
print(x[:9])
# Out:
# Kabelesh

# %%
print(x[-13:-4])
# Out:
# lesh Dhar

# %%
print(x[-13:-4:2])
# Out:
# ls hr

# %%
print(x[-3:-14:-2])
# Out:
# hrh sl

# %%
y = slice(2,8)
print(x[y])
# Out:
# belesh

# %%
a = "Happy"

# %%
print(a[0])
print(a[0:2])
print(a[0:3])
print(a[0:4])
print(a[0:5])
# Out:
# H
# Ha
# Hap
# Happ
# Happy

# %%
print(a[-1])
print(a[-2:])
print(a[-3:])
print(a[-4:])
print(a[-5:])
# Out:
# y
# py
# ppy
# appy
# Happy
